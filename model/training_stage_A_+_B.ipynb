# %%
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
import torch, torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models, utils, datasets, transforms
import torchvision.utils as vutils
import os, time, glob, random, contextlib, shutil
import torchvision.transforms as T
from torch.amp import GradScaler, autocast
from torch.optim.lr_scheduler import LambdaLR
from PIL import Image, ImageFile
# Out:
# Mounted at /content/drive

# %%
ImageFile.LOAD_TRUNCATED_IMAGES = True
local_root = "/content/cartoon-data"
os.makedirs(local_root, exist_ok=True)

drive_root = "/content/drive/MyDrive/cartoon-classification"

# copy ALL real photos
src_real = os.path.join(drive_root, "real_photos_clean")
dst_real = os.path.join(local_root, "real_photos_clean")

# ✅ copy ONLY Gumball cartoons
src_cart = os.path.join(drive_root, "cartoon_modern_clean", "TRAIN", "Gumball")
dst_cart = os.path.join(local_root, "cartoon_modern_clean", "TRAIN", "Gumball")

# %%
def copy_tree_with_progress(src, dst):
    if os.path.exists(dst):
        print(f"{dst} already exists, skipping copy ✅")
        return

    print(f"Copying {src} -> {dst} ...")
    os.makedirs(dst, exist_ok=True)

    # count files first (for tqdm total)
    total_files = sum(len(files) for _, _, files in os.walk(src))

    copied = 0
    for root, dirs, files in os.walk(src):
        # replicate directory structure
        rel_path = os.path.relpath(root, src)
        dst_path = os.path.join(dst, rel_path)
        os.makedirs(dst_path, exist_ok=True)

        for file in files:
            src_file = os.path.join(root, file)
            dst_file = os.path.join(dst_path, file)
            shutil.copy2(src_file, dst_file)
            copied += 1
            tqdm.write(f"Copied {copied}/{total_files}", end="\r")

    print("\n✅ Done.")

copy_tree_with_progress(src_real, dst_real)
copy_tree_with_progress(src_cart, dst_cart)
# Out:
# Copying /content/drive/MyDrive/cartoon-classification/real_photos_clean -> /content/cartoon-data/real_photos_clean ...
# Copied 9802/9802
# ✅ Done.
# Copying /content/drive/MyDrive/cartoon-classification/cartoon_modern_clean/TRAIN/Gumball -> /content/cartoon-data/cartoon_modern_clean/TRAIN/Gumball ...
# Copied 9794/9794
# ✅ Done.

# %%
X_ROOT = "/content/cartoon-data/real_photos_clean"
Y_ROOT_GUMBALL = "/content/cartoon-data/cartoon_modern_clean/TRAIN/Gumball"
OUT_ROOT = "/content/drive/MyDrive/cartoon-classification/cyclegan_gumball"
os.makedirs(OUT_ROOT, exist_ok=True)
IMG_EXTS = (".jpg", ".jpeg", ".png", ".webp", ".bmp")

# %%
class UnpairedDataset(Dataset):
    """
    Unpaired X ~ real photos, Y ~ Gumball cartoons.
    IMPORTANT: no random crop/flip here, just Resize -> keeps structure.
    """
    def __init__(self, path_x, path_y, subset_size=None, img_size=256):
        super().__init__()

        def list_imgs(root):
            pat = os.path.join(root, "**", "*")
            files = sorted(
                p for p in glob.glob(pat, recursive=True)
                if os.path.isfile(p) and p.lower().endswith(IMG_EXTS)
            )
            return files

        self.x_files = list_imgs(path_x)
        self.y_files = list_imgs(path_y)

        if subset_size is not None:
            random.seed(42)
            if len(self.x_files) > subset_size:
                self.x_files = random.sample(self.x_files, subset_size)
            if len(self.y_files) > subset_size:
                self.y_files = random.sample(self.y_files, subset_size)

        if not self.x_files:
            raise RuntimeError(f"No X images at {path_x}")
        if not self.y_files:
            raise RuntimeError(f"No Y images at {path_y}")

        # *** NO random crop / flip: just resize to square ***
        self.tx = T.Compose([
            T.Resize((img_size, img_size), antialias=True),
            T.ToTensor(),
            T.Normalize([0.5]*3, [0.5]*3),
        ])
        self.ty = T.Compose([
            T.Resize((img_size, img_size), antialias=True),
            T.ToTensor(),
            T.Normalize([0.5]*3, [0.5]*3),
        ])

    def __len__(self):
        return max(len(self.x_files), len(self.y_files))

    def __getitem__(self, idx):
        x_path = self.x_files[idx % len(self.x_files)]
        y_path = self.y_files[random.randint(0, len(self.y_files) - 1)]
        x = Image.open(x_path).convert("RGB")
        y = Image.open(y_path).convert("RGB")
        return self.tx(x), self.ty(y)


def build_loader(img_size, subset=None):
    ds = UnpairedDataset(X_ROOT, Y_ROOT_GUMBALL, subset_size=subset, img_size=img_size)
    print(f"Dataset sizes: X={len(ds.x_files)}  Y={len(ds.y_files)}", flush=True)
    dl = DataLoader(
        ds,
        batch_size=BATCH,
        shuffle=True,
        num_workers=0,
        drop_last=True,
        pin_memory=(DEVICE == "cuda"),
    )
    print(f"🔧 batches/epoch={len(dl)}  img={img_size}px  batch={BATCH}")
    return dl

# %%
class ResnetBlock(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.block = nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(dim, dim, 3, bias=False),
            nn.InstanceNorm2d(dim, affine=False, track_running_stats=False),
            nn.ReLU(True),
            nn.ReflectionPad2d(1),
            nn.Conv2d(dim, dim, 3, bias=False),
            nn.InstanceNorm2d(dim, affine=False, track_running_stats=False),
        )

    def forward(self, x):
        return x + self.block(x)


class ResnetGenerator(nn.Module):
    """
    9-block ResNet generator.
    """
    def __init__(self, in_c=3, out_c=3, n_blocks=9):
        super().__init__()
        model = [
            nn.ReflectionPad2d(3),
            nn.Conv2d(in_c, 64, 7, bias=False),
            nn.InstanceNorm2d(64, affine=False, track_running_stats=False),
            nn.ReLU(True),
        ]
        c = 64
        # Downsample x2, x4
        for _ in range(2):
            model += [
                nn.Conv2d(c, c*2, 3, 2, 1, bias=False),
                nn.InstanceNorm2d(c*2, affine=False, track_running_stats=False),
                nn.ReLU(True),
            ]
            c *= 2
        # Residual blocks
        for _ in range(n_blocks):
            model += [ResnetBlock(c)]
        # Upsample back
        for _ in range(2):
            model += [
                nn.ConvTranspose2d(c, c//2, 3, 2, 1, 1, bias=False),
                nn.InstanceNorm2d(c//2, affine=False, track_running_stats=False),
                nn.ReLU(True),
            ]
            c //= 2
        model += [
            nn.ReflectionPad2d(3),
            nn.Conv2d(c, out_c, 7),
            nn.Tanh(),
        ]
        self.net = nn.Sequential(*model)

    def forward(self, x):
        return self.net(x)


class PatchDiscriminator(nn.Module):
    def __init__(self, in_c=3, n_layers=3):
        super().__init__()
        layers = [
            nn.Conv2d(in_c, 64, 4, 2, 1),
            nn.LeakyReLU(0.2, True),
        ]
        c = 64
        for _ in range(1, n_layers):
            layers += [
                nn.Conv2d(c, c*2, 4, 2, 1, bias=False),
                nn.InstanceNorm2d(c*2, affine=False, track_running_stats=False),
                nn.LeakyReLU(0.2, True),
            ]
            c *= 2
        layers += [nn.Conv2d(c, 1, 4, 1, 1)]
        self.model = nn.Sequential(*layers)

    def forward(self, x):
        return self.model(x)


def gan_loss_lsgan(pred, is_real: bool):
    target = torch.ones_like(pred) if is_real else torch.zeros_like(pred)
    return F.mse_loss(pred, target)

# %%
# ------------- HELPERS -------------
def save_sample(x, y, fake_y, rec_x, step, out_dir, tag, max_n=4):
    n = min(max_n, x.size(0), y.size(0))
    grid = torch.cat([x[:n], y[:n], fake_y[:n], rec_x[:n]], dim=0)
    grid = (grid.clamp(-1, 1) + 1) * 0.5
    os.makedirs(out_dir, exist_ok=True)
    out = os.path.join(out_dir, f"{tag}_{step:07d}.png")
    vutils.save_image(grid, out, nrow=n)
    print(f"🖼️  sample → {out}", flush=True)


def make_lr_scheduler(optimizer, total_epochs):
    keep_epochs = int(total_epochs * LR_KEEP_FRAC)
    decay_epochs = max(1, total_epochs - keep_epochs)

    def lr_lambda(epoch):
        if epoch < keep_epochs:
            return 1.0
        return max(0.0, 1.0 - float(epoch - keep_epochs) / float(decay_epochs))

    return LambdaLR(optimizer, lr_lambda=lr_lambda)


def train_stage(
    stage_name,
    img_size,
    epochs,
    lr_g,
    lr_d,
    lambda_cyc,
    lambda_id_max,
    id_warmup_epochs,
    out_root,
    g_init_path=None,
    f_init_path=None,
    start_step=0,
):
    print(f"\n===== {stage_name} @ {img_size}px | epochs={epochs}, lr_g={lr_g}, lr_d={lr_d}, "
          f"λ_cyc={lambda_cyc}, λ_id_max={lambda_id_max} =====")
    samples_dir = os.path.join(out_root, "samples")
    ckpts_dir   = os.path.join(out_root, "checkpoints")
    os.makedirs(samples_dir, exist_ok=True)
    os.makedirs(ckpts_dir, exist_ok=True)

    dl = build_loader(img_size, SUBSET)

    G  = ResnetGenerator(n_blocks=9).to(DEVICE)
    Fm = ResnetGenerator(n_blocks=9).to(DEVICE)
    DX = PatchDiscriminator().to(DEVICE)
    DY = PatchDiscriminator().to(DEVICE)

    for m in (G, Fm, DX, DY):
        m.to(memory_format=torch.channels_last)

    if g_init_path and os.path.exists(g_init_path):
        print("Loading G from:", g_init_path)
        G.load_state_dict(torch.load(g_init_path, map_location=DEVICE), strict=True)
    if f_init_path and os.path.exists(f_init_path):
        print("Loading F from:", f_init_path)
        Fm.load_state_dict(torch.load(f_init_path, map_location=DEVICE), strict=True)

    g_opt = torch.optim.Adam(
        list(G.parameters()) + list(Fm.parameters()),
        lr=lr_g, betas=(0.5, 0.999)
    )
    d_opt = torch.optim.Adam(
        list(DX.parameters()) + list(DY.parameters()),
        lr=lr_d, betas=(0.5, 0.999)
    )

    g_sched = make_lr_scheduler(g_opt, epochs)
    d_sched = make_lr_scheduler(d_opt, epochs)

    use_cuda = (DEVICE == "cuda")
    amp_ctx  = autocast(device_type="cuda", dtype=torch.float16) if use_cuda else contextlib.nullcontext()
    g_scaler = GradScaler(device="cuda") if use_cuda else None
    d_scaler = GradScaler(device="cuda") if use_cuda else None

    step = start_step
    last_g_path = None
    last_f_path = None

    for ep in range(1, epochs+1):
        t0 = time.time()

        # identity weight ramp
        if id_warmup_epochs <= 0:
            lambda_id = lambda_id_max
        else:
            ramp = min(1.0, ep / float(id_warmup_epochs))
            lambda_id = lambda_id_max * ramp

        print(f"\n🌀 {stage_name} Epoch {ep}/{epochs} | λ_id={lambda_id:.3f}", flush=True)
        print(f"   lr_G={g_opt.param_groups[0]['lr']:.6g}, lr_D={d_opt.param_groups[0]['lr']:.6g}", flush=True)

        # epoch stats
        d_loss_sum = 0.0
        g_loss_sum = 0.0
        cyc_sum    = 0.0
        idt_sum    = 0.0
        advg_sum   = 0.0
        advf_sum   = 0.0
        num_steps  = 0

        for x, y in dl:
            x = x.to(DEVICE, non_blocking=True).to(memory_format=torch.channels_last)
            y = y.to(DEVICE, non_blocking=True).to(memory_format=torch.channels_last)

            # --- D step ---
            with torch.no_grad(), amp_ctx:
                fake_y = G(x)
                fake_x = Fm(y)

            d_opt.zero_grad(set_to_none=True)
            with amp_ctx:
                dx_real = DX(x)
                dx_fake = DX(fake_x)
                dy_real = DY(y)
                dy_fake = DY(fake_y)

                d_loss = (
                    gan_loss_lsgan(dx_real, True) +
                    gan_loss_lsgan(dx_fake, False) +
                    gan_loss_lsgan(dy_real, True) +
                    gan_loss_lsgan(dy_fake, False)
                ) * 0.5

            if use_cuda:
                d_scaler.scale(d_loss).backward()
                d_scaler.step(d_opt)
                d_scaler.update()
            else:
                d_loss.backward()
                d_opt.step()

            # --- G/F step ---
            g_opt.zero_grad(set_to_none=True)
            with amp_ctx:
                fake_y = G(x);   pred_dy = DY(fake_y)
                fake_x = Fm(y);  pred_dx = DX(fake_x)

                adv_g = gan_loss_lsgan(pred_dy, True)
                adv_f = gan_loss_lsgan(pred_dx, True)

                rec_x = Fm(fake_y)
                rec_y = G(fake_x)
                cyc   = F.l1_loss(rec_x, x) + F.l1_loss(rec_y, y)

                if lambda_id > 0.0:
                    id_x = G(y)
                    id_y = Fm(x)
                    idt  = F.l1_loss(id_x, y) + F.l1_loss(id_y, x)
                else:
                    idt = torch.zeros((), device=DEVICE, dtype=cyc.dtype)

                g_loss = adv_g + adv_f + lambda_cyc*cyc + lambda_id*idt

            if use_cuda:
                g_scaler.scale(g_loss).backward()
                g_scaler.step(g_opt)
                g_scaler.update()
            else:
                g_loss.backward()
                g_opt.step()

            # accumulate stats
            d_loss_sum += d_loss.item()
            g_loss_sum += g_loss.item()
            cyc_sum    += cyc.item()
            idt_sum    += idt.item()
            advg_sum   += adv_g.item()
            advf_sum   += adv_f.item()
            num_steps  += 1

            if step % 400 == 0:
                print(
                    f"[{stage_name} ep {ep:02d}] step {step:07d} | "
                    f"D={d_loss.item():.3f} | G={g_loss.item():.3f} | "
                    f"advG={adv_g.item():.3f} | advF={adv_f.item():.3f} | "
                    f"cyc={cyc.item():.3f} | idt={idt.item():.3f}",
                    flush=True
                )

            if step % 2000 == 0:
                with torch.inference_mode(), amp_ctx:
                    save_sample(
                        x.detach().cpu(), y.detach().cpu(),
                        fake_y.detach().cpu(), rec_x.detach().cpu(),
                        step, samples_dir,
                        tag=stage_name.replace(" ", "_"),
                    )
            step += 1

        # end epoch: print epoch-avg stats
        if num_steps > 0:
            print(
                f"📊 {stage_name} Epoch {ep} stats | "
                f"D_avg={d_loss_sum/num_steps:.3f} | "
                f"G_avg={g_loss_sum/num_steps:.3f} | "
                f"advG_avg={advg_sum/num_steps:.3f} | "
                f"advF_avg={advf_sum/num_steps:.3f} | "
                f"cyc_avg={cyc_sum/num_steps:.3f} | "
                f"idt_avg={idt_sum/num_steps:.3f}",
                flush=True
            )

        tag = stage_name.replace(" ", "").lower()
        last_g_path = os.path.join(ckpts_dir, f"G_{img_size}_{tag}_ep{ep}.pt")
        last_f_path = os.path.join(ckpts_dir, f"F_{img_size}_{tag}_ep{ep}.pt")
        torch.save(G.state_dict(), last_g_path)
        torch.save(Fm.state_dict(), last_f_path)
        print(f"💾 saved {stage_name} epoch {ep} → {last_g_path}")
        print(f"⏱ epoch took {(time.time()-t0)/60:.1f} min")

        g_sched.step()
        d_sched.step()

    return last_g_path, last_f_path, step

# %%
# train_gumball_cyclegan_fixed.py
# Two-stage CycleGAN for real -> Gumball-only cartoon
# StageA: 256px pretrain (moderate style, strong identity)
# StageB: 512px finetune (stronger style)

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
BATCH = 4
SUBSET = None

LAMBDA_CYC_STAGEA = 5.0
LAMBDA_ID_STAGEA  = 15.0
ID_WARMUP_STAGEA  = 5

LAMBDA_CYC_STAGEB = 2.0
LAMBDA_ID_STAGEB  = 0.0
ID_WARMUP_STAGEB  = 0

STAGEA_IMG   = 256
STAGEA_EPOCH = 50
STAGEA_LR_G  = 2e-4
STAGEA_LR_D  = 2e-4

STAGEB_IMG   = 512
STAGEB_EPOCH = 25
STAGEB_LR_G  = 1e-4
STAGEB_LR_D  = 1e-4

# %%
# ================= MAIN: StageA then StageB =================
if __name__ == "__main__":
    # ----- Stage A: 256px from scratch -----
    OUT_A = os.path.join(OUT_ROOT, "StageA_256_new")
    os.makedirs(OUT_A, exist_ok=True)

    print(f"\n🚀 Training StageA_256 from scratch for {STAGEA_EPOCH} epochs...")
    g_256_path, f_256_path, _ = train_stage(
        stage_name="StageA_256",
        img_size=STAGEA_IMG,
        epochs=STAGEA_EPOCH,
        lr_g=STAGEA_LR_G,
        lr_d=STAGEA_LR_D,
        lambda_cyc=LAMBDA_CYC_STAGEA,
        lambda_id_max=LAMBDA_ID_STAGEA,
        id_warmup_epochs=ID_WARMUP_STAGEA,
        out_root=OUT_A,
        g_init_path=None,
        f_init_path=None,
        start_step=0,
    )

    print("✅ StageA_256 finished.")
    print("   Last G:", g_256_path)
    print("   Last F:", f_256_path)

    # ----- Stage B: 512px finetune from StageA -----
    OUT_B = os.path.join(OUT_ROOT, "StageB_512_new")
    os.makedirs(OUT_B, exist_ok=True)

    print(f"\n🔁 Starting StageB_512 from StageA weights for {STAGEB_EPOCH} epochs...")

    _g_512_path, _f_512_path, _ = train_stage(
        stage_name="StageB_512",
        img_size=STAGEB_IMG,
        epochs=STAGEB_EPOCH,
        lr_g=STAGEB_LR_G,
        lr_d=STAGEB_LR_D,
        lambda_cyc=LAMBDA_CYC_STAGEB,
        lambda_id_max=LAMBDA_ID_STAGEB,
        id_warmup_epochs=ID_WARMUP_STAGEB,
        out_root=OUT_B,
        g_init_path=g_256_path,
        f_init_path=f_256_path,
        start_step=0,
    )

    print("✅ StageB_512 training finished.")
# Out:
# 🚀 Training StageA_256 from scratch for 50 epochs...
#
# ===== StageA_256 @ 256px | epochs=50, lr_g=0.0002, lr_d=0.0002, λ_cyc=5.0, λ_id_max=15.0 =====
# Dataset sizes: X=9802  Y=9794
# 🔧 batches/epoch=2450  img=256px  batch=4
#
# 🌀 StageA_256 Epoch 1/50 | λ_id=3.000
#    lr_G=0.0002, lr_D=0.0002
# [StageA_256 ep 01] step 0000000 | D=1.264 | G=9.838 | advG=0.681 | advF=0.847 | cyc=1.041 | idt=1.035
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/samples/StageA_256_0000000.png
# [StageA_256 ep 01] step 0000400 | D=0.482 | G=5.336 | advG=0.436 | advF=0.252 | cyc=0.658 | idt=0.453
# [StageA_256 ep 01] step 0000800 | D=0.379 | G=3.280 | advG=0.540 | advF=0.298 | cyc=0.319 | idt=0.282
# [StageA_256 ep 01] step 0001200 | D=0.330 | G=3.529 | advG=0.511 | advF=0.378 | cyc=0.348 | idt=0.299
# [StageA_256 ep 01] step 0001600 | D=0.374 | G=3.049 | advG=0.590 | advF=0.300 | cyc=0.273 | idt=0.265
# [StageA_256 ep 01] step 0002000 | D=0.425 | G=2.957 | advG=0.516 | advF=0.329 | cyc=0.274 | idt=0.247
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/samples/StageA_256_0002000.png
# [StageA_256 ep 01] step 0002400 | D=0.531 | G=3.148 | advG=0.455 | advF=0.265 | cyc=0.317 | idt=0.282
# 📊 StageA_256 Epoch 1 stats | D_avg=0.423 | G_avg=3.600 | advG_avg=0.460 | advF_avg=0.383 | cyc_avg=0.361 | idt_avg=0.317
# 💾 saved StageA_256 epoch 1 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/checkpoints/G_256_stagea_256_ep1.pt
# ⏱ epoch took 9.9 min
#
# 🌀 StageA_256 Epoch 2/50 | λ_id=6.000
#    lr_G=0.0002, lr_D=0.0002
# [StageA_256 ep 02] step 0002800 | D=0.375 | G=3.416 | advG=0.461 | advF=0.500 | cyc=0.237 | idt=0.212
# [StageA_256 ep 02] step 0003200 | D=0.420 | G=4.033 | advG=0.761 | advF=0.298 | cyc=0.283 | idt=0.260
# [StageA_256 ep 02] step 0003600 | D=0.330 | G=4.299 | advG=0.529 | advF=0.568 | cyc=0.342 | idt=0.249
# [StageA_256 ep 02] step 0004000 | D=0.392 | G=3.681 | advG=0.434 | advF=0.557 | cyc=0.277 | idt=0.217
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/samples/StageA_256_0004000.png
# [StageA_256 ep 02] step 0004400 | D=0.344 | G=3.300 | advG=0.463 | advF=0.408 | cyc=0.243 | idt=0.203
# [StageA_256 ep 02] step 0004800 | D=0.375 | G=3.427 | advG=0.631 | advF=0.425 | cyc=0.246 | idt=0.190
# 📊 StageA_256 Epoch 2 stats | D_avg=0.361 | G_avg=3.759 | advG_avg=0.633 | advF_avg=0.428 | cyc_avg=0.275 | idt_avg=0.220
# 💾 saved StageA_256 epoch 2 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/checkpoints/G_256_stagea_256_ep2.pt
# ⏱ epoch took 9.8 min
#
# 🌀 StageA_256 Epoch 3/50 | λ_id=9.000
#    lr_G=0.0002, lr_D=0.0002
# [StageA_256 ep
→ /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/checkpoints/G_256_stagea_256_ep34.pt
# ⏱ epoch took 9.8 min
#
# 🌀 StageA_256 Epoch 35/50 | λ_id=15.000
#    lr_G=0.000128, lr_D=0.000128
# [StageA_256 ep 35] step 0083600 | D=0.324 | G=3.100 | advG=0.849 | advF=0.391 | cyc=0.141 | idt=0.077
# [StageA_256 ep 35] step 0084000 | D=0.277 | G=2.998 | advG=0.990 | advF=0.325 | cyc=0.161 | idt=0.059
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/samples/StageA_256_0084000.png
# [StageA_256 ep 35] step 0084400 | D=0.281 | G=2.804 | advG=1.007 | advF=0.280 | cyc=0.131 | idt=0.058
# [StageA_256 ep 35] step 0084800 | D=0.365 | G=2.575 | advG=0.617 | advF=0.342 | cyc=0.137 | idt=0.062
# [StageA_256 ep 35] step 0085200 | D=0.369 | G=3.144 | advG=0.699 | advF=0.295 | cyc=0.173 | idt=0.086
# [StageA_256 ep 35] step 0085600 | D=0.311 | G=3.014 | advG=0.852 | advF=0.300 | cyc=0.148 | idt=0.075
# 📊 StageA_256 Epoch 35 stats | D_avg=0.297 | G_avg=2.876 | advG_avg=0.835 | advF_avg=0.332 | cyc_avg=0.145 | idt_avg=0.065
# 💾 saved StageA_256 epoch 35 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/checkpoints/G_256_stagea_256_ep35.pt
# ⏱ epoch took 9.8 min
#
# 🌀 StageA_256 Epoch 36/50 | λ_id=15.000
#    lr_G=0.00012, lr_D=0.00012
# [StageA_256 ep 36] step 0086000 | D=0.300 | G=2.693 | advG=0.803 | advF=0.292 | cyc=0.149 | idt=0.057
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/samples/StageA_256_0086000.png
# [StageA_256 ep 36] step 0086400 | D=0.327 | G=2.867 | advG=0.665 | advF=0.310 | cyc=0.154 | idt=0.075
# [StageA_256 ep 36] step 0086800 | D=0.326 | G=2.428 | advG=0.692 | advF=0.337 | cyc=0.118 | idt=0.054
# [StageA_256 ep 36] step 0087200 | D=0.281 | G=2.612 | advG=0.782 | advF=0.330 | cyc=0.137 | idt=0.054
# [StageA_256 ep 36] step 0087600 | D=0.287 | G=2.669 | advG=0.873 | advF=0.364 | cyc=0.127 | idt=0.053
# [StageA_256 ep 36] step 0088000 | D=0.305 | G=2.520 | advG=0.851 | advF=0.280 | cyc=0.134 | idt=0.048
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/samples/StageA_256_0088000.png
# 📊 StageA_256 Epoch 36 stats | D_avg=0.297 | G_avg=2.828 | advG_avg=0.836 | advF_avg=0.326 | cyc_avg=0.142 | idt_avg=0.064
# 💾 saved StageA_256 epoch 36 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/checkpoints/G_256_stagea_256_ep36.pt
# ⏱ epoch took 9.7 min
#
# 🌀 StageA_256 Epoch 37/50 | λ_id=15.000
#    lr_G=0.000112, lr_D=0.000112
# [StageA_256 ep 37] step 0088400 | D=0.344 | G=2.418 | advG=0.792 | advF=0.272 | cyc=0.125 | idt=0.048
# [StageA_256 ep 37] step 0088800 | D=0.299 | G=2.992 | advG=0.869 | advF=0.357 | cyc=0.137 | idt=0.072
# [StageA_256 ep 37] step 0089200 | D=0.342 | G=2.459 | advG=0.739 | advF=0.319 | cyc=0.131 | idt=0.050
# [StageA_256 ep 37] step 0089600 | D=0.267 | G=3.203 | advG=0.980 | advF=0.318 | cyc=0.156 | idt=0.075
# [StageA_256 ep 37] step 0090000 | D=0.286 | G=3.037 | advG=0.832 | advF=0.314 | cyc=0.160 | idt=0.073
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/samples/StageA_256_0090000.png
# [StageA_256 ep 37] step 0090400 | D=0.305 | G=2.899 | advG=0.861 | advF=0.286 | cyc=0.155 | idt=0.065
# 📊 StageA_256 Epoch 37 stats | D_avg=0.297 | G_avg=2.797 | advG_avg=0.836 | advF_avg=0.324 | cyc_avg=0.141 | idt_avg=0.062
# 💾 saved StageA_256 epoch 37 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/checkpoints/G_256_stagea_256_ep37.pt
# ⏱ epoch took 9.7 min
#
# 🌀 StageA_256 Epoch 38/50 | λ_id=15.000
#    lr_G=0.000104, lr_D=0.000104
# [StageA_256 ep 38] step 0090800 | D=0.311 | G=2.825 | advG=0.817 | advF=0.287 | cyc=0.144 | idt=0.067
# [StageA_256 ep 38] step 0091200 | D=0.326 | G=2.552 | advG=0.783 | advF=0.310 | cyc=0.130 | idt=0.054
# [StageA_256 ep 38] step 0091600 | D=0.292 | G=2.392 | advG=0.793 | advF=0.294 | cyc=0.112 | idt=0.050
# [StageA_256 ep 38] step 0092000 | D=0.264 | G=2.950 | advG=0.741 | advF=0.353 | cyc=0.161 | idt=0.070
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/samples/StageA_256_0092000.png
# [StageA_256 ep 38] step 0092400 | D=0.252 | G=2.606 | advG=0.814 | advF=0.341 | cyc=0.130 | idt=0.053
# [StageA_256 ep 38] step 0092800 | D=0.323 | G=2.874 | advG=0.857 | advF=0.293 | cyc=0.130 | idt=0.071
# 📊 StageA_256 Epoch 38 stats | D_avg=0.298 | G_avg=2.752 | advG_avg=0.833 | advF_avg=0.320 | cyc_avg=0.138 | idt_avg=0.060
# 💾 saved StageA_256 epoch 38 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/checkpoints/G_256_stagea_256_ep38.pt
# ⏱ epoch took 9.7 min
#
# 🌀 StageA_256 Epoch 39/50 | λ_id=15.000
#    lr_G=9.6e-05, lr_D=9.6e-05
# [StageA_256 ep 39] step 0093200 | D=0.246 | G=2.755 | advG=0.888 | advF=0.346 | cyc=0.129 | idt=0.058
# [StageA_256 ep 39] step 0093600 | D=0.330 | G=2.759 | advG=0.734 | advF=0.333 | cyc=0.141 | idt=0.066
# [StageA_256 ep 39] step 0094000 | D=0.246 | G=2.754 | advG=0.866 | advF=0.341 | cyc=0.140 | idt=0.057
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/samples/StageA_256_0094000.png
# [StageA_256 ep 39] step 0094400 | D=0.336 | G=2.583 | advG=0.817 | advF=0.288 | cyc=0.133 | idt=0.054
# [StageA_256 ep 39] step 0094800 | D=0.270 | G=3.134 | advG=0.939 | advF=0.314 | cyc=0.155 | idt=0.074
# [StageA_256 ep 39] step 0095200 | D=0.297 | G=2.940 | advG=0.874 | advF=0.301 | cyc=0.161 | idt=0.064
# 📊 StageA_256 Epoch 39 stats | D_avg=0.295 | G_avg=2.717 | advG_avg=0.837 | advF_avg=0.318 | cyc_avg=0.136 | idt_avg=0.059
# 💾 saved StageA_256 epoch 39 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/checkpoints/G_256_stagea_256_ep39.pt
# ⏱ epoch took 9.7 min
#
# 🌀 StageA_256 Epoch 40/50 | λ_id=15.000
#    lr_G=8.8e-05, lr_D=8.8e-05
# [StageA_256 ep 40] step 0095600 | D=0.303 | G=2.740 | advG=0.836 | advF=0.277 | cyc=0.138 | idt=0.062
# [StageA_256 ep 40] step 0096000 | D=0.338 | G=2.279 | advG=0.705 | advF=0.259 | cyc=0.126 | idt=0.046
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/samples/StageA_256_
pt
# ⏱ epoch took 9.7 min
#
# 🌀 StageA_256 Epoch 43/50 | λ_id=15.000
#    lr_G=6.4e-05, lr_D=6.4e-05
# ...
# 📊 StageA_256 Epoch 43 stats | D_avg=0.294 | G_avg=2.573 | advG_avg=0.832 | advF_avg=0.306 | cyc_avg=0.128 | idt_avg=0.053
# 💾 saved StageA_256 epoch 43 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/checkpoints/G_256_stagea_256_ep43.pt
# ⏱ epoch took 9.7 min
#
# 🌀 StageA_256 Epoch 44/50 | λ_id=15.000
#    lr_G=5.6e-05, lr_D=5.6e-05
# [StageA_256 ep 44] step 0105600 | D=0.309 | G=2.517 | advG=0.956 | advF=0.263 | cyc=0.126 | idt=0.044
# [StageA_256 ep 44] step 0106000 | D=0.293 | G=2.525 | advG=0.915 | advF=0.266 | cyc=0.128 | idt=0.047
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/samples/StageA_256_0106000.png
# [StageA_256 ep 44] step 0106400 | D=0.292 | G=2.532 | advG=0.746 | advF=0.328 | cyc=0.142 | idt=0.050
# [StageA_256 ep 44] step 0106800 | D=0.277 | G=2.328 | advG=0.744 | advF=0.324 | cyc=0.116 | idt=0.045
# [StageA_256 ep 44] step 0107200 | D=0.318 | G=2.417 | advG=0.817 | advF=0.274 | cyc=0.123 | idt=0.047
# [StageA_256 ep 44] step 0107600 | D=0.332 | G=2.549 | advG=0.871 | advF=0.308 | cyc=0.127 | idt=0.049
# 📊 StageA_256 Epoch 44 stats | D_avg=0.294 | G_avg=2.539 | advG_avg=0.830 | advF_avg=0.304 | cyc_avg=0.126 | idt_avg=0.052
# 💾 saved StageA_256 epoch 44 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/checkpoints/G_256_stagea_256_ep44.pt
# ⏱ epoch took 9.7 min
#
# 🌀 StageA_256 Epoch 45/50 | λ_id=15.000
#    lr_G=4.8e-05, lr_D=4.8e-05
# [StageA_256 ep 45] step 0108000 | D=0.276 | G=2.596 | advG=0.862 | advF=0.303 | cyc=0.128 | idt=0.053
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/samples/StageA_256_0108000.png
# [StageA_256 ep 45] step 0108400 | D=0.280 | G=2.371 | advG=0.867 | advF=0.284 | cyc=0.114 | idt=0.043
# [StageA_256 ep 45] step 0108800 | D=0.296 | G=2.501 | advG=0.748 | advF=0.312 | cyc=0.115 | idt=0.058
# [StageA_256 ep 45] step 0109200 | D=0.293 | G=2.786 | advG=0.854 | advF=0.317 | cyc=0.144 | idt=0.060
# [StageA_256 ep 45] step 0109600 | D=0.354 | G=3.339 | advG=0.868 | advF=0.297 | cyc=0.164 | idt=0.090
# [StageA_256 ep 45] step 0110000 | D=0.278 | G=2.408 | advG=0.811 | advF=0.303 | cyc=0.115 | idt=0.048
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/samples/StageA_256_0110000.png
# 📊 StageA_256 Epoch 45 stats | D_avg=0.293 | G_avg=2.506 | advG_avg=0.830 | advF_avg=0.301 | cyc_avg=0.124 | idt_avg=0.050
# 💾 saved StageA_256 epoch 45 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/checkpoints/G_256_stagea_256_ep45.pt
# ⏱ epoch took 9.7 min
#
# 🌀 StageA_256 Epoch 46/50 | λ_id=15.000
#    lr_G=4e-05, lr_D=4e-05
# [StageA_256 ep 46] step 0110400 | D=0.276 | G=2.468 | advG=0.826 | advF=0.296 | cyc=0.119 | idt=0.050
# [StageA_256 ep 46] step 0110800 | D=0.306 | G=2.323 | advG=0.851 | advF=0.242 | cyc=0.118 | idt=0.043
# [StageA_256 ep 46] step 0111200 | D=0.287 | G=2.437 | advG=0.826 | advF=0.328 | cyc=0.122 | idt=0.045
# [StageA_256 ep 46] step 0111600 | D=0.284 | G=2.251 | advG=0.691 | advF=0.295 | cyc=0.119 | idt=0.045
# [StageA_256 ep 46] step 0112000 | D=0.301 | G=2.403 | advG=0.800 | advF=0.298 | cyc=0.118 | idt=0.048
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/samples/StageA_256_0112000.png
# [StageA_256 ep 46] step 0112400 | D=0.297 | G=2.452 | advG=0.792 | advF=0.295 | cyc=0.128 | idt=0.048
# 📊 StageA_256 Epoch 46 stats | D_avg=0.293 | G_avg=2.473 | advG_avg=0.826 | advF_avg=0.297 | cyc_avg=0.123 | idt_avg=0.049
# 💾 saved StageA_256 epoch 46 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/checkpoints/G_256_stagea_256_ep46.pt
# ⏱ epoch took 9.7 min
#
# 🌀 StageA_256 Epoch 47/50 | λ_id=15.000
#    lr_G=3.2e-05, lr_D=3.2e-05
# [StageA_256 ep 47] step 0112800 | D=0.318 | G=2.632 | advG=0.782 | advF=0.319 | cyc=0.145 | idt=0.054
# [StageA_256 ep 47] step 0113200 | D=0.283 | G=2.521 | advG=0.861 | advF=0.249 | cyc=0.138 | idt=0.048
# [StageA_256 ep 47] step 0113600 | D=0.284 | G=2.494 | advG=0.809 | advF=0.299 | cyc=0.129 | idt=0.049
# [StageA_256 ep 47] step 0114000 | D=0.337 | G=2.253 | advG=0.710 | advF=0.288 | cyc=0.113 | idt=0.046
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/samples/StageA_256_0114000.png
# [StageA_256 ep 47] step 0114400 | D=0.283 | G=2.319 | advG=0.818 | advF=0.270 | cyc=0.111 | idt=0.045
# [StageA_256 ep 47] step 0114800 | D=0.271 | G=2.413 | advG=0.869 | advF=0.277 | cyc=0.123 | idt=0.044
# 📊 StageA_256 Epoch 47 stats | D_avg=0.291 | G_avg=2.443 | advG_avg=0.827 | advF_avg=0.296 | cyc_avg=0.121 | idt_avg=0.048
# 💾 saved StageA_256 epoch 47 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/checkpoints/G_256_stagea_256_ep47.pt
# ⏱ epoch took 9.7 min
#
# 🌀 StageA_256 Epoch 48/50 | λ_id=15.000
#    lr_G=2.4e-05, lr_D=2.4e-05
# [StageA_256 ep 48] step 0115200 | D=0.331 | G=2.316 | advG=0.791 | advF=0.260 | cyc=0.115 | idt=0.046
# [StageA_256 ep 48] step 0115600 | D=0.293 | G=2.257 | advG=0.792 | advF=0.260 | cyc=0.120 | idt=0.040
# [StageA_256 ep 48] step 0116000 | D=0.280 | G=2.387 | advG=0.787 | advF=0.286 | cyc=0.126 | idt=0.046
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/samples/StageA_256_0116000.png
# [StageA_256 ep 48] step 0116400 | D=0.336 | G=2.126 | advG=0.768 | advF=0.241 | cyc=0.095 | idt=0.043
# [StageA_256 ep 48] step 0116800 | D=0.288 | G=2.234 | advG=0.805 | advF=0.268 | cyc=0.108 | idt=0.042
# [StageA_256 ep 48] step 0117200 | D=0.295 | G=2.583 | advG=0.840 | advF=0.265 | cyc=0.134 | idt=0.054
# 📊 StageA_256 Epoch 48 stats | D_avg=0.292 | G_avg=2.412 | advG_avg=0.821 | advF_avg=0.293 | cyc_avg=0.119 | idt_avg=0.047
# 💾 saved StageA_256 epoch 48 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/checkpoints/G_256_stagea_256_ep48.pt
# ⏱ epoch took 9.7 min
#
# 🌀 StageA_256 Epoch 49/50 | λ_id=15.000
#    lr_G=1.6e-05, lr_D=1.6e-05
# [StageA_256 ep 49] step 0117600 | D=0.316 | G=2.298 | advG=0.811 | advF=0.264 | cyc=0.116 | idt=0.043
# [StageA_256 ep 49] step 0118000 | D=0.306 | G=2.089 | advG=0.738 | advF=0.269 | cyc=0.102 | idt=0.038
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/samples/StageA_256_0118000.png
# [StageA_256 ep 49] step 0118400 | D=0.255 | G=2.282 | advG=0.830 | advF=0.291 | cyc=0.118 | idt=0.038
# [StageA_256 ep 49] step 0118800 | D=0.277 | G=2.407 | advG=0.793 | advF=0.332 | cyc=0.109 | idt=0.049
# [StageA_256 ep 49] step 0119200 | D=0.273 | G=2.123 | advG=0.735 | advF=0.267 | cyc=0.100 | idt=0.041
# [StageA_256 ep 49] step 0119600 | D=0.294 | G=2.480 | advG=0.807 | advF=0.315 | cyc=0.119 | idt=0.051
# [StageA_256 ep 49] step 0120000 | D=0.297 | G=2.471 | advG=0.859 | advF=0.272 | cyc=0.126 | idt=0.047
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/samples/StageA_256_0120000.png
# 📊 StageA_256 Epoch 49 stats | D_avg=0.292 | G_avg=2.383 | advG_avg=0.818 | advF_avg=0.290 | cyc_avg=0.117 | idt_avg=0.046
# 💾 saved StageA_256 epoch 49 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/checkpoints/G_256_stagea_256_ep49.pt
# ⏱ epoch took 9.7 min
#
# 🌀 StageA_256 Epoch 50/50 | λ_id=15.000
#    lr_G=8e-06, lr_D=8e-06
# [StageA_256 ep 50] step 0120400 | D=0.284 | G=2.317 | advG=0.813 | advF=0.275 | cyc=0.112 | idt=0.045
# [StageA_256 ep 50] step 0120800 | D=0.293 | G=2.436 | advG=0.803 | advF=0.236 | cyc=0.133 | idt=0.049
# [StageA_256 ep 50] step 0121200 | D=0.362 | G=2.238 | advG=0.787 | advF=0.299 | cyc=0.110 | idt=0.040
# [StageA_256 ep 50] step 0121600 | D=0.331 | G=2.238 | advG=0.735 | advF=0.330 | cyc=0.110 | idt=0.041
# [StageA_256 ep 50] step 0122000 | D=0.294 | G=2.476 | advG=0.814 | advF=0.272 | cyc=0.131 | idt=0.049
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/samples/StageA_256_0122000.png
# [StageA_256 ep 50] step 0122400 | D=0.291 | G=2.271 | advG=0.769 | advF=0.263 | cyc=0.117 | idt=0.044
# 📊 StageA_256 Epoch 50 stats | D_avg=0.291 | G_avg=2.360 | advG_avg=0.815 | advF_avg=0.287 | cyc_avg=0.116 | idt_avg=0.045
# 💾 saved StageA_256 epoch 50 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/checkpoints/G_256_stagea_256_ep50.pt
# ⏱ epoch took 9.7 min
# ✅ StageA_256 finished.
#    Last G: /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/checkpoints/G_256_stagea_256_ep50.pt
#    Last F: /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/checkpoints/F_256_stagea_256_ep50.pt
#
# 🔁 Starting StageB_512 from StageA weights for 25 epochs...
#
# ===== StageB_512 @ 512px | epochs=25, lr_g=0.0001, lr_d=0.0001, λ_cyc=2.0, λ_id_max=0.0 =====
# Dataset sizes: X=9802  Y=9794
# 🔧 batches/epoch=2450  img=512px  batch=4
# Loading G from: /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/checkpoints/G_256_stagea_256_ep50.pt
# Loading F from: /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/checkpoints/F_256_stagea_256_ep50.pt
#
# 🌀 StageB_512 Epoch 1/25 | λ_id=0.000
#    lr_G=0.0001, lr_D=0.0001
# [StageB_512 ep 01] step 0000000 | D=1.631 | G=3.130 | advG=1.569 | advF=1.293 | cyc=0.134 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_
| idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0008000.png
# [StageB_512 ep 04] step 0008400 | D=0.450 | G=0.844 | advG=0.332 | advF=0.292 | cyc=0.110 | idt=0.000
# [StageB_512 ep 04] step 0008800 | D=0.500 | G=0.699 | advG=0.277 | advF=0.267 | cyc=0.077 | idt=0.000
# [StageB_512 ep 04] step 0009200 | D=0.445 | G=0.908 | advG=0.337 | advF=0.298 | cyc=0.137 | idt=0.000
# [StageB_512 ep 04] step 0009600 | D=0.478 | G=0.879 | advG=0.342 | advF=0.294 | cyc=0.122 | idt=0.000
# 📊 StageB_512 Epoch 4 stats | D_avg=0.478 | G_avg=0.821 | advG_avg=0.327 | advF_avg=0.273 | cyc_avg=0.110 | idt_avg=0.000
# 💾 saved StageB_512 epoch 4 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep4.pt
# ⏱ epoch took 22.8 min
#
# 🌀 StageB_512 Epoch 5/25 | λ_id=0.000
#    lr_G=0.0001, lr_D=0.0001
# [StageB_512 ep 05] step 0010000 | D=0.449 | G=0.845 | advG=0.384 | advF=0.307 | cyc=0.077 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0010000.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1092490952.py in <cell line: 0>()
#     472     print(f"\n🔁 Starting StageB_512 from StageA weights for {STAGEB_EPOCH} epochs...")
#     473
# --> 474     _g_512_path, _f_512_path, _ = train_stage(
#     475         stage_name="StageB_512",
#     476         img_size=STAGEB_IMG,
#
# /tmp/ipython-input-1092490952.py in train_stage(stage_name, img_size, epochs, lr_g, lr_d, lambda_cyc, lambda_id_max, id_warmup_epochs, out_root, g_init_path, f_init_path, start_step)
#     378
#     379             if use_cuda:
# --> 380                 g_scaler.scale(g_loss).backward()
#     381                 g_scaler.step(g_opt)
#     382                 g_scaler.update()
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     623                 inputs=inputs,
#     624             )
# --> 625         torch.autograd.backward(
#     626             self, gradient, retain_graph, create_graph, inputs=inputs
#     627         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     352     # some Python versions print out the first line of a multi-line function
#     353     # calls in the traceback and some print out the last line
# --> 354     _engine_run_backward(
#     355         tensors,
#     356         grad_tensors_,
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     839         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     840     try:
# --> 841         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     842             t_outputs, *args, **kwargs
#     843         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
# ================= MAIN: RESUME SPECIFICALLY FROM STAGE B EPOCH 4 =================
if __name__ == "__main__":

    # ----- Skip Stage A (you already finished 50 epochs) -----
    OUT_A = os.path.join(OUT_ROOT, "StageA_256_new")
    g_256_path = os.path.join(OUT_A, "checkpoints/G_256_stagea_256_ep50.pt")
    f_256_path = os.path.join(OUT_A, "checkpoints/F_256_stagea_256_ep50.pt")

    print("✔ Using StageA epoch 50 checkpoints:")
    print("G:", g_256_path)
    print("F:", f_256_path)

    # ----- Resume Stage B from epoch 4 -----
    OUT_B = os.path.join(OUT_ROOT, "StageB_512_new")
    os.makedirs(OUT_B, exist_ok=True)

    g_resume = os.path.join(OUT_B, "checkpoints/G_512_stageb_512_ep4.pt")
    f_resume = os.path.join(OUT_B, "checkpoints/F_512_stageb_512_ep4.pt")

    print("\n🔁 Resuming StageB from EPOCH 4:")
    print("G:", g_resume)
    print("F:", f_resume)

    # compute correct start step (epoch * batches_per_epoch)
    start_step = 4 * 2450     # approx 9800
    print("start_step =", start_step)

    # resume training from epoch 4
    _g_last, _f_last, _ = train_stage(
        stage_name="StageB_512",
        img_size=STAGEB_IMG,
        epochs=STAGEB_EPOCH,          # stays 25; sched still works
        lr_g=STAGEB_LR_G,
        lr_d=STAGEB_LR_D,
        lambda_cyc=LAMBDA_CYC_STAGEB,
        lambda_id_max=LAMBDA_ID_STAGEB,
        id_warmup_epochs=ID_WARMUP_STAGEB,
        out_root=OUT_B,
        g_init_path=g_resume,
        f_init_path=f_resume,
        start_step=start_step
    )

    print("🎉 StageB resumed and running from epoch 4.")
# Out:
# ✔ Using StageA epoch 50 checkpoints:
# G: /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/checkpoints/G_256_stagea_256_ep50.pt
# F: /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/checkpoints/F_256_stagea_256_ep50.pt
#
# 🔁 Resuming StageB from EPOCH 4:
# G: /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep4.pt
# F: /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/F_512_stageb_512_ep4.pt
# start_step = 9800
#
# ===== StageB_512 @ 512px | epochs=25, lr_g=0.0001, lr_d=0.0001, λ_cyc=2.0, λ_id_max=0.0 =====
# Dataset sizes: X=9802  Y=9794
# 🔧 batches/epoch=2450  img=512px  batch=4
# Loading G from: /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep4.pt
# Loading F from: /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/F_512_stageb_512_ep4.pt
#
# 🌀 StageB_512 Epoch 1/25 | λ_id=0.000
#    lr_G=0.0001, lr_D=0.0001
# [StageB_512 ep 01] step 0010000 | D=0.505 | G=0.704 | advG=0.274 | advF=0.254 | cyc=0.088 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0010000.png
# [StageB_512 ep 01] step 0010400 | D=0.513 | G=0.712 | advG=0.250 | advF=0.291 | cyc=0.086 | idt=0.000
# [StageB_512 ep 01] step 0010800 | D=0.507 | G=0.710 | advG=0.264 | advF=0.270 | cyc=0.088 | idt=0.000
# [StageB_512 ep 01] step 0011200 | D=0.516 | G=0.719 | advG=0.267 | advF=0.259 | cyc=0.096 | idt=0.000
# [StageB_512 ep 01] step 0011600 | D=0.514 | G=0.742 | advG=0.256 | advF=0.265 | cyc=0.111 | idt=0.000
# [StageB_512 ep 01] step 0012000 | D=0.491 | G=0.815 | advG=0.282 | advF=0.279 | cyc=0.127 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0012000.png
# 📊 StageB_512 Epoch 1 stats | D_avg=0.510 | G_avg=0.724 | advG_avg=0.268 | advF_avg=0.265 | cyc_avg=0.095 | idt_avg=0.000
# 💾 saved StageB_512 epoch 1 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep1.pt
# ⏱ epoch took 22.7 min
#
# 🌀 StageB_512 Epoch 2/25 | λ_id=0.000
#    lr_G=0.0001, lr_D=0.0001
# [StageB_512 ep 02] step 0012400 | D=0.503 | G=0.700 | advG=0.271 | advF=0.238 | cyc=0.096 | idt=0.000
# [StageB_512 ep 02] step 0012800 | D=0.485 | G=0.700 | advG=0.275 | advF=0.258 | cyc=0.084 | idt=0.000
# [StageB_512 ep 02] step 0013200 | D=0.489 | G=0.727 | advG=0.288 | advF=0.262 | cyc=0.089 | idt=0.000
# [StageB_512 ep 02] step 0013600 | D=0.498 | G=0.762 | advG=0.266 | advF=0.279 | cyc=0.109 | idt=0.000
# [StageB_512 ep 02] step 0014000 | D=0.498 | G=0.708 | advG=0.267 | advF=0.259 | cyc=0.091 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0014000.png
# [StageB_512 ep 02] step 0014400 | D=0.511 | G=0.666 | advG=0.274 | advF=0.262 | cyc=0.065 | idt=0.000
# 📊 StageB_512 Epoch 2 stats | D_avg=0.498 | G_avg=0.725 | advG_avg=0.279 | advF_avg=0.264 | cyc_avg=0.092 | idt_avg=0.000
# 💾 saved StageB_512 epoch 2 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep2.pt
# ⏱ epoch took 22.7 min
#
# 🌀 StageB_512 Epoch 3/25 | λ_id=0.000
#    lr_G=0.0001, lr_D=0.0001
# [StageB_512 ep 03] step 0014800 | D=0.484 | G=0.687 | advG=0.286 | advF=0.250 | cyc=0.075 | idt=0.000
# [StageB_512 ep 03] step 0015200 | D=0.493 | G=0.715 | advG=0.267 | advF=0.263 | cyc=0.093 | idt=0.000
# [StageB_512 ep 03] step 0015600 | D=0.540 | G=0.698 | advG=0.290 | advF=0.233 | cyc=0.088 | idt=0.000
# [StageB_512 ep 03] step 0016000 | D=0.489 | G=0.724 | advG=0.276 | advF=0.274 | cyc=0.087 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0016000.png
# [StageB_512 ep 03] step 0016400 | D=0.493 | G=0.737 | advG=0.266 | advF=0.264 | cyc=0.103 | idt=0.000
# [StageB_512 ep 03] step 0016800 | D=0.514 | G=0.775 | advG=0.303 | advF=0.274 | cyc=0.099 | idt=0.000
# 📊 StageB_512 Epoch 3 stats | D_avg=0.488 | G_avg=0.752 | advG_avg=0.299 | advF_avg=0.266 | cyc_avg=0.093 | idt_avg=0.000
# 💾 saved StageB_512 epoch 3 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep3.pt
# ⏱ epoch took 22.7 min
#
# 🌀 StageB_512 Epoch 4/25 | λ_id=0.000
#    lr_G=0.0001, lr_D=0.0001
# [StageB_512 ep 04] step 0017200 | D=0.497 | G=0.789 | advG=0.306 | advF=0.248 | cyc=0.118 | idt=0.000
# [StageB_512 ep 04] step 0017600 | D=0.454 | G=0.768 | advG=0.342 | advF=0.265 | cyc=0.081 | idt=0.000
# [StageB_512 ep 04] step 0018000 | D=0.528 | G=0.826 | advG=0.329 | advF=0.244 | cyc=0.126 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0018000.png
# [StageB_512 ep 04] step 0018400 | D=0.499 | G=0.760 | advG=0.294 | advF=0.262 | cyc=0.102 | idt=0.000
# [StageB_512 ep 04] step 0018800 | D=0.467 | G=0.795 | advG=0.318 | advF=0.266 | cyc=0.105 | idt=0.000
# [StageB_512 ep 04] step 0019200 | D=0.467 | G=0.812 | advG=0.308 | advF=0.322 | cyc=0.091 | idt=0.000
# 📊 StageB_512 Epoch 4 stats | D_avg=0.479 | G_avg=0.786 | advG_avg=0.322 | advF_avg=0.269 | cyc_avg=0.097 | idt_avg=0.000
# 💾 saved StageB_512 epoch 4 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep4.pt
# ⏱ epoch took 22.7 min
#
# 🌀 StageB_512 Epoch 5/25 | λ_id=0.000
#    lr_G=0.0001, lr_D=0.0001
# [StageB_512 ep 05] step 0019600 | D=0.448 | G=0.777 | advG=0.341 | advF=0.248 | cyc=0.094 | idt=0.000
# [StageB_512 ep 05] step 0020000 | D=0.508 | G=0.792 | advG=0.337 | advF=0.303 | cyc=0.076 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0020000.png
# [StageB_512 ep 05] step 0020400 | D=0.497 | G=0.734 | advG=0.296 | advF=0.270 | cyc=0.084 | idt=0.000
# [StageB_512 ep 05] step 0020800 | D=0.457 | G=0.834 | advG=0.401 | advF=0.265 | cyc=0.084 | idt=0.000
# [StageB_512 ep 05] step 0021200 | D=0.504 | G=0.794 | advG=0.300 | advF=0.279 | cyc=0.108 | idt=0.000
# [StageB_512 ep 05] step 0021600 | D=0.462 | G=0.885 | advG=0.371 | advF=0.281 | cyc=0.116 | idt=0.000
# [StageB_512 ep 05] step 0022000 | D=0.430 | G=0.909 | advG=0.370 | advF=0.269 | cyc=0.135 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0022000.png
# 📊 StageB_512 Epoch 5 stats | D_avg=0.470 | G_avg=0.818 | advG_avg=0.345 | advF_avg=0.271 | cyc_avg=0.101 | idt_avg=0.000
# 💾 saved StageB_512 epoch 5 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep5.pt
# ⏱ epoch took 22.8 min
#
# 🌀 StageB_512 Epoch 6/25 | λ_id=0.000
#    lr_G=0.0001, lr_D=0.0001
# [StageB_512 ep 06] step 0022400 | D=0.453 | G=0.849 | advG=0.339 | advF=0.316 | cyc=0.097 | idt=0.000
# [StageB_512 ep 06] step 0022800 | D=0.411 | G=0.934 | advG=0.445 | advF=0.272 | cyc=0.108 | idt=0.000
# [StageB_512 ep 06] step 0023200 | D=0.410 | G=0.870 | advG=0.409 | advF=0.286 | cyc=0.087 | idt=0.000
# [StageB_512 ep 06] step 0023600 | D=0.494 | G=0.797 | advG=0.321 | advF=0.269 | cyc=0.104 | idt=0.000
# [StageB_512 ep 06] step 0024000 | D=0.443 | G=0.861 | advG=0.399 | advF=0.271 | cyc=0.095 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0024000.png
# [StageB_512 ep 06] step 0024400 | D=0.465 | G=0.764 | advG=0.312 | advF=0.254 | cyc=0.099 | idt=0.000
# 📊 StageB_512 Epoch 6 stats | D_avg=0.463 | G_avg=0.845 | advG_avg=0.366 | advF_avg=0.272 | cyc_avg=0.104 | idt_avg=0.000
# 💾 saved StageB_512 epoch 6 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep6.pt
# ⏱ epoch took 22.8 min
#
# 🌀 StageB_512 Epoch 7/25 | λ_id=0.000
#    lr_G=0.0001, lr_D=0.0001
# [StageB_512 ep 07] step 0024800 | D=0.422 | G=0.798 | advG=0.353 | advF=0.262 | cyc=0.091 | idt=0.000
# [StageB_512 ep 07] step 0025200 | D=0.475 | G=0.840 | advG=0.373 | advF=0.263 | cyc=0.102 | idt=0.000
# [StageB_512 ep 07] step 0025600 | D=0.416 | G=0.918 | advG=0.422 | advF=0.279 | cyc=0.109 | idt=0.000
# [StageB_512 ep 07] step 0026000 | D=0.462 | G=1.081 | advG=0.458 | advF=0.323 | cyc=0.150 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0026000.png
# [StageB_512 ep 07] step 0026400 | D=0.464 | G=0.846 | advG=0.369 | advF=0.254 | cyc=0.111 | idt=0.000
# [StageB_512 ep 07] step 0026800 | D=0.494 | G=0.796 | advG=0.326 | advF=0.268 | cyc=0.101 | idt=0.000
# 📊 StageB_512 Epoch 7 stats | D_avg=0.457 | G_avg=0.868 | advG_avg=0.384 | advF_avg=0.274 | cyc_avg=0.105 | idt_avg=0.000
# 💾 saved StageB_512 epoch 7 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep7.pt
# ⏱ epoch took 22.8 min
#
# 🌀 StageB_512 Epoch 8/25 | λ_id=0.000
#    lr_G=0.0001, lr_D=0.0001
# [StageB_512 ep 08] step 0027200 | D=0.502 | G=0.786 | advG=0.341 | advF=0.241 | cyc=0.102 | idt=0.000
# [StageB_512 ep 08] step 0027600 | D=0.432 | G=0.825 | advG=0.343 | advF=0.276 | cyc=0.103 | idt=0.000
# [StageB_512 ep 08] step 0028000 | D=0.491 | G=0.905 | advG=0.389 | advF=0.283 | cyc=0.117 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0028000.png
# [StageB_512 ep 08] step 0028400 | D=0.434 | G=0.849 | advG=0.355 | advF=0.280 | cyc=0.107 | idt=0.000
# [StageB_512 ep 08] step 0028800 | D=0.434 | G=0.854 | advG=0.422 | advF=0.255 | cyc=0.089 | idt=0.000
# [StageB_512 ep 08] step 0029200 | D=0.448 | G=0.879 | advG=0.376 | advF=0.270 | cyc=0.117 | idt=0.000
# 📊 StageB_512 Epoch 8 stats | D_avg=0.454 | G_avg=0.884 | advG_avg=0.397 | advF_avg=0.274 | cyc_avg=0.106 | idt_avg=0.000
# 💾 saved StageB_512 epoch 8 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep8.pt
# ⏱ epoch took 22.8 min
#
# 🌀 StageB_512 Epoch 9/25 | λ_id=0.000
#    lr_G=0.0001, lr_D=0.0001
# [StageB_512 ep 09] step 0029600 | D=0.475 | G=0.799 | advG=0.362 | advF=0.277 | cyc=0.080 | idt=0.000
# [StageB_512 ep 09] step 0030000 | D=0.376 | G=1.037 | advG=0.494 | advF=0.320 | cyc=0.111 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0030000.png
# [StageB_512 ep 09] step 0030400 | D=0.432 | G=0.916 | advG=0.359 | advF=0.309 | cyc=0.124 | idt=0.000
# [StageB_512 ep 09] step 0030800 | D=0.428 | G=0.955 | advG=0.439 | advF=0.293 | cyc=0.111 | idt=0.000
# [StageB_512 ep 09] step 0031200 | D=0.434 | G=1.020 | advG=0.531 | advF=0.267 | cyc=0.111 | idt=0.000
# [StageB_512 ep 09] step 0031600 | D=0.430 | G=0.868 | advG=0.392 | advF=0.254 | cyc=0.111 | idt=0.000
# 📊 StageB_512 Epoch 9 stats | D_avg=0.450 | G_avg=0.899 | advG_avg=0.409 | advF_avg=0.276 | cyc_avg=0.107 | idt_avg=0.000
# 💾 saved StageB_512 epoch 9 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep9.pt
# ⏱ epoch took 22.8 min
#
# 🌀 StageB_512 Epoch 10/25 | λ_id=0.000
#    lr_G=0.0001, lr_D=0.0001
# [StageB_512 ep 10] step 0032000 | D=0.464 | G=0.816 | advG=0.416 | advF=0.235 | cyc=0.082 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0032000.png
# [StageB_512 ep 10] step 0032400 | D=0.424 | G=0.913 | advG=0.442 | advF=0.270 | cyc=0.101 | idt=0.000
# [StageB_512 ep 10] step 0032800 | D=0.450 | G=0.929 | advG=0.435 | advF=0.260 | cyc=0.117 | idt=0.000
# [StageB_512 ep 10] step 0033200 | D=0.469 | G=0.865 | advG=0.371 | advF=0.290 | cyc=0.102 | idt=0.000
# [StageB_512 ep 10] step 0033600 | D=0.433 | G=0.921 | advG=0.387 | advF=0.329 | cyc=0.102 | idt=0.000
# [StageB_512 ep 10] step 0034000 | D=0.436 | G=0.971 | advG=0.417 | advF=0.261 | cyc=0.147 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0034000.png
# 📊 StageB_512 Epoch 10 stats | D_avg=0.446 | G_avg=0.913 | advG_avg=0.420 | advF_avg=0.277 | cyc_avg=0.108 | idt_avg=0.000
# 💾 saved StageB_512 epoch 10 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep10.pt
# ⏱ epoch took 22.8 min
#
# 🌀 StageB_512 Epoch 11/25 | λ_id=0.000
#    lr_G=0.0001, lr_D=0.0001
# [StageB_512 ep 11] step 0034400 | D=0.420 | G=0.959 | advG=0.432 | advF=0.285 | cyc=0.121 | idt=0.000
# [StageB_512 ep 11] step 0034800 | D=0.435 | G=0.889 | advG=0.412 | advF=0.262 | cyc=0.108 | idt=0.000
# [StageB_512 ep 11] step 0035200 | D=0.414 | G=0.983 | advG=0.432 | advF=0.309 | cyc=0.121 | idt=0.000
# [StageB_512 ep 11] step 0035600 | D=0.472 | G=0.877 | advG=0.384 | advF=0.297 | cyc=0.098 | idt=0.000
# [StageB_512 ep 11] step 0036000 | D=0.504 | G=0.916 | advG=0.401 | advF=0.280 | cyc=0.118 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0036000.png
# [StageB_512 ep 11] step 0036400 | D=0.434 | G=0.859 | advG=0.404 | advF=0.276 | cyc=0.090 | idt=0.000
# 📊 StageB_512 Epoch 11 stats | D_avg=0.443 | G_avg=0.923 | advG_avg=0.430 | advF_avg=0.277 | cyc_avg=0.108 | idt_avg=0.000
# 💾 saved StageB_512 epoch 11 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep11.pt
# ⏱ epoch took 22.8 min
#
# 🌀 StageB_512 Epoch 12/25 | λ_id=0.000
#    lr_G=0.0001, lr_D=0.0001
# [StageB_512 ep 12] step 0036800 | D=0.395 | G=0.963 | advG=0.469 | advF=0.275 | cyc=0.110 | idt=0.000
# [StageB_512 ep 12] step 0037200 | D=0.430 | G=0.953 | advG=0.415 | advF=0.271 | cyc=0.133 | idt=0.000
# [StageB_512 ep 12] step 0037600 | D=0.427 | G=0.950 | advG=0.495 | advF=0.264 | cyc=0.095 | idt=0.000
# [StageB_512 ep 12] step 0038000 | D=0.443 | G=0.846 | advG=0.380 | advF=0.269 | cyc=0.098 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0038000.png
# [StageB_512 ep 12] step 0038400 | D=0.391 | G=0.965 | advG=0.426 | advF=0.343 | cyc=0.098 | idt=0.000
# [StageB_512 ep 12] step 0038800 | D=0.448 | G=0.977 | advG=0.519 | advF=0.250 | cyc=0.104 | idt=0.000
# 📊 StageB_512 Epoch 12 stats | D_avg=0.440 | G_avg=0.935 | advG_avg=0.440 | advF_avg=0.277 | cyc_avg=0.108 | idt_avg=0.000
# 💾 saved StageB_512 epoch 12 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep12.pt
# ⏱ epoch took 22.8 min
#
# 🌀 StageB_512 Epoch 13/25 | λ_id=0.000
#    lr_G=0.0001, lr_D=0.0001
# [StageB_512 ep 13] step 0039200 | D=0.452 | G=0.805 | advG=0.342 | advF=0.260 | cyc=0.101 | idt=0.000
# [StageB_512 ep 13] step 0039600 | D=0.460 | G=0.945 | advG=0.514 | advF=0.257 | cyc=0.087 | idt=0.000
# [StageB_512 ep 13] step 0040000 | D=0.483 | G=0.864 | advG=0.409 | advF=0.252 | cyc=0.101 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0040000.png
# [StageB_512 ep 13] step 0040400 | D=0.517 | G=0.939 | advG=0.439 | advF=0.267 | cyc=0.116 | idt=0.000
# [StageB_512 ep 13] step 0040800 | D=0.388 | G=1.057 | advG=0.573 | advF=0.269 | cyc=0.108 | idt=0.000
# [StageB_512 ep 13] step 0041200 | D=0.449 | G=0.956 | advG=0.444 | advF=0.306 | cyc=0.103 | idt=0.000
# [StageB_512 ep 13] step 0041600 | D=0.486 | G=1.045 | advG=0.624 | advF=0.229 | cyc=0.095 | idt=0.000
# 📊 StageB_512 Epoch 13 stats | D_avg=0.438 | G_avg=0.943 | advG_avg=0.449 | advF_avg=0.277 | cyc_avg=0.109 | idt_avg=0.000
# 💾 saved StageB_512 epoch 13 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep13.pt
# ⏱ epoch took 22.8 min
#
# 🌀 StageB_512 Epoch 14/25 | λ_id=0.000
#    lr_G=9.23077e-05, lr_D=9.23077e-05
# [StageB_512 ep 14] step 0042000 | D=0.400 | G=0.982 | advG=0.505 | advF=0.255 | cyc=0.111 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0042000.png
# [StageB_512 ep 14] step 0042400 | D=0.519 | G=0.907 | advG=0.406 | advF=0.281 | cyc=0.110 | idt=0.000
# [StageB_512 ep 14] step 0042800 | D=0.436 | G=0.969 | advG=0.488 | advF=0.271 | cyc=0.105 | idt=0.000
# [StageB_512 ep 14] step 0043200 | D=0.396 | G=1.010 | advG=0.491 | advF=0.292 | cyc=0.114 | idt=0.000
# [StageB_512 ep 14] step 0043600 | D=0.364 | G=1.123 | advG=0.541 | advF=0.323 | cyc=0.129 | idt=0.000
# [StageB_512 ep 14] step 0044000 | D=0.410 | G=0.926 | advG=0.472 | advF=0.254 | cyc=0.100 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0044000.png
# 📊 StageB_512 Epoch 14 stats | D_avg=0.432 | G_avg=0.942 | advG_avg=0.452 | advF_avg=0.277 | cyc_avg=0.107 | idt_avg=0.000
# 💾 saved StageB_512 epoch 14 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep14.pt
# ⏱ epoch took 22.8 min
#
# 🌀 StageB_512 Epoch 15/25 | λ_id=0.000
#    lr_G=8.46154e-05, lr_D=8.46154e-05
# [StageB_512 ep 15] step 0044400 | D=0.447 | G=0.848 | advG=0.396 | advF=0.262 | cyc=0.095 | idt=0.000
# [StageB_512 ep 15] step 0044800 | D=0.402 | G=0.935 | advG=0.452 | advF=0.281 | cyc=0.101 | idt=0.000
# [StageB_512 ep 15] step 0045200 | D=0.427 | G=0.894 | advG=0.417 | advF=0.289 | cyc=0.094 | idt=0.000
# [StageB_512 ep 15] step 0045600 | D=0.446 | G=0.945 | advG=0.519 | advF=0.238 | cyc=0.094 | idt=0.000
# [StageB_512 ep 15] step 0046000 | D=0.452 | G=0.908 | advG=0.422 | advF=0.276 | cyc=0.105 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0046000.png
# [StageB_512 ep 15] step 0046400 | D=0.475 | G=0.911 | advG=0.435 | advF=0.276 | cyc=0.100 | idt=0.000
# 📊 StageB_512 Epoch 15 stats | D_avg=0.427 | G_avg=0.950 | advG_avg=0.464 | advF_avg=0.276 | cyc_avg=0.106 | idt_avg=0.000
# 💾 saved StageB_512 epoch 15 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep15.pt
# ⏱ epoch took 22.7 min
#
# 🌀 StageB_512 Epoch 16/25 | λ_id=0.000
#    lr_G=7.69231e-05, lr_D=7.69231e-05
# [StageB_512 ep 16] step 0046800 | D=0.471 | G=0.924 | advG=0.439 | advF=0.293 | cyc=0.096 | idt=0.000
# [StageB_512 ep 16] step 0047200 | D=0.441 | G=0.897 | advG=0.425 | advF=0.277 | cyc=0.097 | idt=0.000
# [StageB_512 ep 16] step 0047600 | D=0.370 | G=0.985 | advG=0.540 | advF=0.260 | cyc=0.093 | idt=0.000
# [StageB_512 ep 16] step 0048000 | D=0.427 | G=0.939 | advG=0.483 | advF=0.258 | cyc=0.099 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0048000.png
# [StageB_512 ep 16] step 0048400 | D=0.383 | G=0.992 | advG=0.520 | advF=0.258 | cyc=0.108 | idt=0.000
# [StageB_512 ep 16] step 0048800 | D=0.430 | G=0.954 | advG=0.541 | advF=0.233 | cyc=0.090 | idt=0.000
# 📊 StageB_512 Epoch 16 stats | D_avg=0.424 | G_avg=0.953 | advG_avg=0.468 | advF_avg=0.275 | cyc_avg=0.105 | idt_avg=0.000
# 💾 saved StageB_512 epoch 16 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep16.pt
# ⏱ epoch took 22.7 min
#
# 🌀 StageB_512 Epoch 17/25 | λ_id=0.000
#    lr_G=6.92308e-05, lr_D=6.92308e-05
# [StageB_512 ep 17] step 0049200 | D=0.396 | G=1.006 | advG=0.503 | advF=0.282 | cyc=0.111 | idt=0.000
# [StageB_512 ep 17] step 0049600 | D=0.391 | G=0.961 | advG=0.495 | advF=0.271 | cyc=0.097 | idt=0.000
# [StageB_512 ep 17] step 0050000 | D=0.418 | G=0.998 | advG=0.530 | advF=0.287 | cyc=0.091 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0050000.png
# [StageB_512 ep 17] step 0050400 | D=0.408 | G=0.976 | advG=0.499 | advF=0.294 | cyc=0.092 | idt=0.000
# [StageB_512 ep 17] step 0050800 | D=0.373 | G=0.971 | advG=0.491 | advF=0.261 | cyc=0.109 | idt=0.000
# [StageB_512 ep 17] step 0051200 | D=0.381 | G=1.071 | advG=0.591 | advF=0.274 | cyc=0.103 | idt=0.000
# 📊 StageB_512 Epoch 17 stats | D_avg=0.418 | G_avg=0.959 | advG_avg=0.476 | advF_avg=0.275 | cyc_avg=0.104 | idt_avg=0.000
# 💾 saved StageB_512 epoch 17 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep17.pt
# ⏱ epoch took 22.7 min
#
# 🌀 StageB_512 Epoch 18/25 | λ_id=0.000
#    lr_G=6.15385e-05, lr_D=6.15385e-05
# [StageB_512 ep 18] step 0051600 | D=0.413 | G=0.945 | advG=0.423 | advF=0.314 | cyc=0.104 | idt=0.000
# [StageB_512 ep 18] step 0052000 | D=0.394 | G=0.977 | advG=0.489 | advF=0.297 | cyc=0.095 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0052000.png
# [StageB_512 ep 18] step 0052400 | D=0.397 | G=0.982 | advG=0.504 | advF=0.260 | cyc=0.109 | idt=0.000
# [StageB_512 ep 18] step 0052800 | D=0.410 | G=1.002 | advG=0.516 | advF=0.282 | cyc=0.102 | idt=0.000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3822279397.py in <cell line: 0>()
#      27
#      28     # resume training from epoch 4
# ---> 29     _g_last, _f_last, _ = train_stage(
#      30         stage_name="StageB_512",
#      31         img_size=STAGEB_IMG,
#
# /tmp/ipython-input-1655278869.py in train_stage(stage_name, img_size, epochs, lr_g, lr_d, lambda_cyc, lambda_id_max, id_warmup_epochs, out_root, g_init_path, f_init_path, start_step)
#     378
#     379             if use_cuda:
# --> 380                 g_scaler.scale(g_loss).backward()
#     381                 g_scaler.step(g_opt)
#     382                 g_scaler.update()
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     623                 inputs=inputs,
#     624             )
# --> 625         torch.autograd.backward(
#     626             self, gradient, retain_graph, create_graph, inputs=inputs
#     627         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     352     # some Python versions print out the first line of a multi-line function
#     353     # calls in the traceback and some print out the last line
# --> 354     _engine_run_backward(
#     355         tensors,
#     356         grad_tensors_,
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     839         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     840     try:
# --> 841         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     842             t_outputs, *args, **kwargs
#     843         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
# ================= MAIN: RESUME SPECIFICALLY FROM STAGE B EPOCH 18 =================
if __name__ == "__main__":

    # We won't retrain Stage A
    OUT_A = os.path.join(OUT_ROOT, "StageA_256_new")
    g_256_path = os.path.join(OUT_A, "checkpoints/G_256_stagea_256_ep50.pt")
    f_256_path = os.path.join(OUT_A, "checkpoints/F_256_stagea_256_ep50.pt")
    print("✔ Using StageA epoch 50 checkpoints:")
    print("G:", g_256_path)
    print("F:", f_256_path)

    OUT_B = os.path.join(OUT_ROOT, "StageB_512_new")
    os.makedirs(OUT_B, exist_ok=True)

    EPOCH_RESUME = 18  # <--- change this if you ever want a different epoch
    G_NAME = f"G_512_stageb_512_ep{EPOCH_RESUME}.pt"
    F_NAME = f"F_512_stageb_512_ep{EPOCH_RESUME}.pt"

    g_resume = os.path.join(OUT_B, "checkpoints", G_NAME)
    f_resume = os.path.join(OUT_B, "checkpoints", F_NAME)

    print(f"\n🔁 Resuming StageB from EPOCH {EPOCH_RESUME}:")
    print("G:", g_resume)
    print("F:", f_resume)

    remaining_epochs = STAGEB_EPOCH - EPOCH_RESUME  # 25 - 18 = 7
    if remaining_epochs <= 0:
        print("Nothing left to train, StageB is already at or past target epoch.")
    else:
        batches_per_epoch = 2450  # from your logs
        start_step = EPOCH_RESUME * batches_per_epoch
        print("remaining_epochs =", remaining_epochs)
        print("start_step =", start_step)

        _g_last, _f_last, _ = train_stage(
            stage_name="StageB_512",
            img_size=STAGEB_IMG,
            epochs=remaining_epochs,      # just finish 19..25
            lr_g=STAGEB_LR_G,
            lr_d=STAGEB_LR_D,
            lambda_cyc=LAMBDA_CYC_STAGEB,
            lambda_id_max=LAMBDA_ID_STAGEB,
            id_warmup_epochs=ID_WARMUP_STAGEB,
            out_root=OUT_B,
            g_init_path=g_resume,
            f_init_path=f_resume,
            start_step=start_step,
        )

        print(f"🎉 StageB resumed from epoch {EPOCH_RESUME} and finished the remaining epochs.")
# Out:
# ✔ Using StageA epoch 50 checkpoints:
# G: /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/checkpoints/G_256_stagea_256_ep50.pt
# F: /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageA_256_new/checkpoints/F_256_stagea_256_ep50.pt
#
# 🔁 Resuming StageB from EPOCH 18:
# G: /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep18.pt
# F: /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/F_512_stageb_512_ep18.pt
# remaining_epochs = 7
# start_step = 44100
#
# ===== StageB_512 @ 512px | epochs=7, lr_g=0.0001, lr_d=0.0001, λ_cyc=2.0, λ_id_max=0.0 =====
# Dataset sizes: X=9802  Y=9794
# 🔧 batches/epoch=2450  img=512px  batch=4
# Loading G from: /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep18.pt
# Loading F from: /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/F_512_stageb_512_ep18.pt
#
# 🌀 StageB_512 Epoch 1/7 | λ_id=0.000
#    lr_G=0.0001, lr_D=0.0001
# [StageB_512 ep 01] step 0044400 | D=0.507 | G=0.834 | advG=0.264 | advF=0.273 | cyc=0.148 | idt=0.000
# [StageB_512 ep 01] step 0044800 | D=0.498 | G=0.797 | advG=0.262 | advF=0.266 | cyc=0.134 | idt=0.000
# [StageB_512 ep 01] step 0045200 | D=0.527 | G=0.877 | advG=0.274 | advF=0.280 | cyc=0.162 | idt=0.000
# [StageB_512 ep 01] step 0045600 | D=0.501 | G=0.872 | advG=0.296 | advF=0.263 | cyc=0.157 | idt=0.000
# [StageB_512 ep 01] step 0046000 | D=0.497 | G=0.847 | advG=0.281 | advF=0.287 | cyc=0.140 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0046000.png
# [StageB_512 ep 01] step 0046400 | D=0.534 | G=0.774 | advG=0.293 | advF=0.257 | cyc=0.113 | idt=0.000
# 📊 StageB_512 Epoch 1 stats | D_avg=0.510 | G_avg=0.841 | advG_avg=0.274 | advF_avg=0.267 | cyc_avg=0.150 | idt_avg=0.000
# 💾 saved StageB_512 epoch 1 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep1.pt
# ⏱ epoch took 22.7 min
#
# 🌀 StageB_512 Epoch 2/7 | λ_id=0.000
#    lr_G=0.0001, lr_D=0.0001
# [StageB_512 ep 02] step 0046800 | D=0.484 | G=0.824 | advG=0.271 | advF=0.276 | cyc=0.139 | idt=0.000
# [StageB_512 ep 02] step 0047200 | D=0.492 | G=0.816 | advG=0.274 | advF=0.262 | cyc=0.140 | idt=0.000
# [StageB_512 ep 02] step 0047600 | D=0.495 | G=0.737 | advG=0.267 | advF=0.254 | cyc=0.108 | idt=0.000
# [StageB_512 ep 02] step 0048000 | D=0.483 | G=0.778 | advG=0.293 | advF=0.273 | cyc=0.106 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0048000.png
# [StageB_512 ep 02] step 0048400 | D=0.476 | G=0.892 | advG=0.287 | advF=0.300 | cyc=0.152 | idt=0.000
# [StageB_512 ep 02] step 0048800 | D=0.493 | G=0.873 | advG=0.297 | advF=0.271 | cyc=0.152 | idt=0.000
# 📊 StageB_512 Epoch 2 stats | D_avg=0.497 | G_avg=0.828 | advG_avg=0.285 | advF_avg=0.266 | cyc_avg=0.139 | idt_avg=0.000
# 💾 saved StageB_512 epoch 2 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep2.pt
# ⏱ epoch took 22.7 min
#
# 🌀 StageB_512 Epoch 3/7 | λ_id=0.000
#    lr_G=0.0001, lr_D=0.0001
# [StageB_512 ep 03] step 0049200 | D=0.501 | G=0.774 | advG=0.291 | advF=0.255 | cyc=0.114 | idt=0.000
# [StageB_512 ep 03] step 0049600 | D=0.468 | G=0.927 | advG=0.354 | advF=0.249 | cyc=0.162 | idt=0.000
# [StageB_512 ep 03] step 0050000 | D=0.488 | G=0.809 | advG=0.289 | advF=0.278 | cyc=0.121 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0050000.png
# [StageB_512 ep 03] step 0050400 | D=0.518 | G=0.871 | advG=0.350 | advF=0.261 | cyc=0.130 | idt=0.000
# [StageB_512 ep 03] step 0050800 | D=0.479 | G=0.830 | advG=0.335 | advF=0.262 | cyc=0.117 | idt=0.000
# [StageB_512 ep 03] step 0051200 | D=0.522 | G=0.822 | advG=0.273 | advF=0.284 | cyc=0.132 | idt=0.000
# 📊 StageB_512 Epoch 3 stats | D_avg=0.488 | G_avg=0.850 | advG_avg=0.309 | advF_avg=0.266 | cyc_avg=0.138 | idt_avg=0.000
# 💾 saved StageB_512 epoch 3 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep3.pt
# ⏱ epoch took 22.7 min
#
# 🌀 StageB_512 Epoch 4/7 | λ_id=0.000
#    lr_G=0.0001, lr_D=0.0001
# [StageB_512 ep 04] step 0051600 | D=0.484 | G=0.879 | advG=0.351 | advF=0.249 | cyc=0.139 | idt=0.000
# [StageB_512 ep 04] step 0052000 | D=0.482 | G=0.801 | advG=0.303 | advF=0.272 | cyc=0.113 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0052000.png
# [StageB_512 ep 04] step 0052400 | D=0.497 | G=0.976 | advG=0.348 | advF=0.269 | cyc=0.180 | idt=0.000
# [StageB_512 ep 04] step 0052800 | D=0.511 | G=0.769 | advG=0.268 | advF=0.255 | cyc=0.123 | idt=0.000
# [StageB_512 ep 04] step 0053200 | D=0.455 | G=0.856 | advG=0.345 | advF=0.251 | cyc=0.130 | idt=0.000
# [StageB_512 ep 04] step 0053600 | D=0.498 | G=0.834 | advG=0.308 | advF=0.236 | cyc=0.145 | idt=0.000
# 📊 StageB_512 Epoch 4 stats | D_avg=0.477 | G_avg=0.876 | advG_avg=0.335 | advF_avg=0.268 | cyc_avg=0.136 | idt_avg=0.000
# 💾 saved StageB_512 epoch 4 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep4.pt
# ⏱ epoch took 22.7 min
#
# 🌀 StageB_512 Epoch 5/7 | λ_id=0.000
#    lr_G=7.5e-05, lr_D=7.5e-05
# [StageB_512 ep 05] step 0054000 | D=0.437 | G=0.849 | advG=0.363 | advF=0.259 | cyc=0.113 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0054000.png
# [StageB_512 ep 05] step 0054400 | D=0.468 | G=0.924 | advG=0.354 | advF=0.279 | cyc=0.146 | idt=0.000
# [StageB_512 ep 05] step 0054800 | D=0.507 | G=0.801 | advG=0.300 | advF=0.237 | cyc=0.132 | idt=0.000
# [StageB_512 ep 05] step 0055200 | D=0.461 | G=0.863 | advG=0.336 | advF=0.254 | cyc=0.136 | idt=0.000
# [StageB_512 ep 05] step 0055600 | D=0.451 | G=0.833 | advG=0.327 | advF=0.250 | cyc=0.128 | idt=0.000
# [StageB_512 ep 05] step 0056000 | D=0.453 | G=0.885 | advG=0.382 | advF=0.265 | cyc=0.119 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0056000.png
# 📊 StageB_512 Epoch 5 stats | D_avg=0.465 | G_avg=0.877 | advG_avg=0.354 | advF_avg=0.267 | cyc_avg=0.128 | idt_avg=0.000
# 💾 saved StageB_512 epoch 5 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep5.pt
# ⏱ epoch took 22.7 min
#
# 🌀 StageB_512 Epoch 6/7 | λ_id=0.000
#    lr_G=5e-05, lr_D=5e-05
# [StageB_512 ep 06] step 0056400 | D=0.431 | G=0.824 | advG=0.331 | advF=0.271 | cyc=0.111 | idt=0.000
# [StageB_512 ep 06] step 0056800 | D=0.427 | G=0.902 | advG=0.393 | advF=0.276 | cyc=0.117 | idt=0.000
# [StageB_512 ep 06] step 0057200 | D=0.450 | G=0.856 | advG=0.400 | advF=0.244 | cyc=0.106 | idt=0.000
# [StageB_512 ep 06] step 0057600 | D=0.436 | G=0.935 | advG=0.416 | advF=0.262 | cyc=0.128 | idt=0.000
# [StageB_512 ep 06] step 0058000 | D=0.421 | G=0.897 | advG=0.435 | advF=0.252 | cyc=0.105 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0058000.png
# [StageB_512 ep 06] step 0058400 | D=0.450 | G=0.896 | advG=0.394 | advF=0.269 | cyc=0.117 | idt=0.000
# 📊 StageB_512 Epoch 6 stats | D_avg=0.453 | G_avg=0.874 | advG_avg=0.368 | advF_avg=0.265 | cyc_avg=0.121 | idt_avg=0.000
# 💾 saved StageB_512 epoch 6 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep6.pt
# ⏱ epoch took 22.7 min
#
# 🌀 StageB_512 Epoch 7/7 | λ_id=0.000
#    lr_G=2.5e-05, lr_D=2.5e-05
# [StageB_512 ep 07] step 0058800 | D=0.431 | G=0.873 | advG=0.409 | advF=0.265 | cyc=0.100 | idt=0.000
# [StageB_512 ep 07] step 0059200 | D=0.414 | G=0.831 | advG=0.374 | advF=0.267 | cyc=0.095 | idt=0.000
# [StageB_512 ep 07] step 0059600 | D=0.448 | G=0.789 | advG=0.346 | advF=0.265 | cyc=0.089 | idt=0.000
# [StageB_512 ep 07] step 0060000 | D=0.467 | G=0.780 | advG=0.344 | advF=0.245 | cyc=0.095 | idt=0.000
# 🖼️  sample → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/samples/StageB_512_0060000.png
# [StageB_512 ep 07] step 0060400 | D=0.450 | G=0.888 | advG=0.354 | advF=0.283 | cyc=0.126 | idt=0.000
# [StageB_512 ep 07] step 0060800 | D=0.452 | G=0.898 | advG=0.366 | advF=0.277 | cyc=0.128 | idt=0.000
# [StageB_512 ep 07] step 0061200 | D=0.466 | G=0.895 | advG=0.390 | advF=0.265 | cyc=0.120 | idt=0.000
# 📊 StageB_512 Epoch 7 stats | D_avg=0.443 | G_avg=0.857 | advG_avg=0.371 | advF_avg=0.263 | cyc_avg=0.111 | idt_avg=0.000
# 💾 saved StageB_512 epoch 7 → /content/drive/MyDrive/cartoon-classification/cyclegan_gumball/StageB_512_new/checkpoints/G_512_stageb_512_ep7.pt
# ⏱ epoch took 22.7 min
# 🎉 StageB resumed from epoch 18 and finished the remaining epochs.
